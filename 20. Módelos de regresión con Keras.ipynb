# %% [markdown]
# # Modelos de regresión con Keras

# %% [markdown]
# ## Introducción

# %% [markdown]
# Como discutimos en los videos, a pesar de la popularidad de bibliotecas más potentes como PyTorch y TensorFlow, estas no son fáciles de usar y tienen una curva de aprendizaje pronunciada. Por ello, para las personas que apenas comienzan a aprender deep learning, no hay una biblioteca mejor para empezar que Keras.
#
# Keras es una API de alto nivel para construir modelos de aprendizaje profundo. Ha ganado popularidad por su facilidad de uso y su simplicidad sintáctica, lo que facilita un desarrollo rápido. Como verás en este laboratorio y en otros del curso, es posible construir redes neuronales muy complejas con Keras utilizando solo unas cuantas líneas de código.
#
# Apreciarás aún más Keras una vez que aprendas a construir modelos profundos utilizando PyTorch y TensorFlow en otros cursos.
#
# Por lo tanto, en este laboratorio aprenderás a utilizar la biblioteca Keras para construir un modelo de regresión.

# %% [markdown]
# ## Objetivos de este cuaderno
# * Cómo utilizar la biblioteca Keras para construir un modelo de regresión
# * Descargar y limpiar el conjunto de datos
# * Construir una red neuronal
# * Entrenar y probar la red

# %% [markdown]
# #### Para usar Keras, también necesitarás instalar un framework backend, como TensorFlow.
#
# Si instalas TensorFlow versión 2.16 o superior, Keras se instalará de forma predeterminada.
#
# Estamos utilizando la versión de TensorFlow para CPU, ya que trabajamos con conjuntos de datos pequeños.
# Puedes instalar la versión de TensorFlow para GPU en tu máquina para acelerar el procesamiento de conjuntos de datos más grandes.

# %% [markdown]
# #### Suprimir los mensajes de advertencia de TensorFlow
#
# Usamos el siguiente código para suprimir los mensajes de advertencia que aparecen al usar la arquitectura CPU en TensorFlow.
#
# Es posible que desees **comentar estas líneas** si estás utilizando la arquitectura GPU.

# %%
import pandas as pd
import numpy as np
import keras

import warnings
warnings.simplefilter('ignore', FutureWarning)
# Out:
# C:\Users\Josue Santana Robled\PycharmProjects\Coursera\.venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %% [markdown]
# Estaremos trabajando con el mismo conjunto de datos que usamos en los videos.
#
# El conjunto de datos trata sobre la resistencia a la compresión de diferentes muestras de concreto, basada en los volúmenes de los distintos ingredientes utilizados para fabricarlas. Los ingredientes incluyen:
#
# * Cemento
# * Escoria de alto horno
# * Ceniza volante
# * Agua
# * Superplastificante
# * Agregado grueso
# * Agregado fino

# %% [markdown]
# ## Descarga ylimpia el dataset

# %% [markdown]
# Vamos a descargar los datos y leerlos en un dataframe de pandas.

# %%
filepath='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv'
concrete_data = pd.read_csv(filepath)

concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# La primera muestra de concreto tiene 540 metros cúbicos de cemento, 0 metros cúbicos de escoria de alto horno, 0 metros cúbicos de ceniza volante, 162 metros cúbicos de agua, 2.5 metros cúbicos de superplastificante, 1040 metros cúbicos de agregado grueso y 676 metros cúbicos de agregado fino.
#
# Una mezcla de concreto de este tipo, con 28 días de edad, tiene una resistencia a la compresión de 79.99 MPa.

# %% [markdown]
# #### Verifiquemos cuántos puntos de datos tenemos

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# Entonces, hay aproximadamente 1000 muestras para entrenar nuestro modelo. Debido a que son pocas muestras, debemos tener cuidado de no sobreajustar (overfit) los datos de entrenamiento.

# %% [markdown]
# Verifiquemos el conjunto de datos para detectar valores faltantes.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# Los datos se ven muy limpios y están listos para ser utilizados en la construcción de nuestro modelo.

# %% [markdown]
# #### Dividir los datos en variables predictoras y variable objetivo

# %% [markdown]
# La variable objetivo en este problema es la resistencia de la muestra de concreto. Por lo tanto, nuestras variables predictoras serán todas las demás columnas.

# %%
concrete_data_columns = concrete_data.columns

# %%
predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# Hagamos una verificación rápida de consistencia (sanity check) de los dataframes de las variables predictoras y de la variable objetivo.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finalmente, el último paso es normalizar los datos, restando la media y dividiendo por la desviación estándar.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Guardemos el número de variables predictoras en n_cols, ya que necesitaremos este número al construir nuestra red.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# ## Importar paquetes de Keras
#
# ##### Vamos a importar el resto de los paquetes de la biblioteca Keras que necesitaremos para construir nuestro modelo de regresión.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input

# %% [markdown]
# ## Construye una red Neuronal

# %% [markdown]
# Definamos una función que cree nuestro modelo de regresión, de manera que podamos llamarla fácilmente cada vez que queramos construir el modelo.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Input(shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))

    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# La función anterior crea un modelo que tiene dos capas ocultas, cada una con 50 unidades ocultas.

# %% [markdown]
# ## Entrenar y probar la red

# %% [markdown]
# Ahora llamemos a la función para crear nuestro modelo.

# %%
# build the model
model = regression_model()

# %% [markdown]
# A continuación, entrenaremos y probaremos el modelo al mismo tiempo utilizando el método fit. Dejaremos fuera el 30% de los datos para validación y entrenaremos el modelo durante 100 épocas.

# %%
# fit the model
model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 1s - 32ms/step - loss: 1642.6890 - val_loss: 1143.1090
# Epoch 2/100
# 23/23 - 0s - 4ms/step - loss: 1502.9733 - val_loss: 1012.8025
# Epoch 3/100
# 23/23 - 0s - 4ms/step - loss: 1269.5928 - val_loss: 807.6794
# Epoch 4/100
# 23/23 - 0s - 4ms/step - loss: 931.2803 - val_loss: 557.2693
# Epoch 5/100
# 23/23 - 0s - 4ms/step - loss: 563.0643 - val_loss: 344.3210
# Epoch 6/100
# 23/23 - 0s - 4ms/step - loss: 321.7903 - val_loss: 239.5842
# Epoch 7/100
# 23/23 - 0s - 4ms/step - loss: 245.9794 - val_loss: 211.4986
# Epoch 8/100
# 23/23 - 0s - 4ms/step - loss: 225.1988 - val_loss: 205.7051
# Epoch 9/100
# 23/23 - 0s - 4ms/step - loss: 211.7592 - val_loss: 202.1484
# Epoch 10/100
# 23/23 - 0s - 4ms/step - loss: 202.6850 - val_loss: 196.6662
# Epoch 11/100
# 23/23 - 0s - 4ms/step - loss: 194.4103 - val_loss: 192.6432
# Epoch 12/100
# 23/23 - 0s - 4ms/step - loss: 187.6250 - val_loss: 189.2095
# Epoch 13/100
# 23/23 - 0s - 4ms/step - loss: 182.4091 - val_loss: 188.7894
# Epoch 14/100
# 23/23 - 0s - 4ms/step - loss: 177.3407 - val_loss: 184.2441
# Epoch 15/100
# 23/23 - 0s - 4ms/step - loss: 173.1777 - val_loss: 179.9347
# Epoch 16/100
# 23/23 - 0s - 4ms/step - loss: 169.2052 - val_loss: 177.8847
# Epoch 17/100
# 23/23 - 0s - 4ms/step - loss: 165.1460 - val_loss: 174.5092
# Epoch 18/100
# 23/23 - 0s - 4ms/step - loss: 161.7924 - val_loss: 171.7398
# Epoch 19/100
# 23/23 - 0s - 4ms/step - loss: 158.8306 - val_loss: 170.8769
# Epoch 20/100
# 23/23 - 0s - 4ms/step - loss: 156.3484 - val_loss: 168.4799
# Epoch 21/100
# 23/23 - 0s - 4ms/step - loss: 153.7291 - val_loss: 169.9532
# Epoch 22/100
# 23/23 - 0s - 4ms/step - loss: 150.7796 - val_loss: 167.2350
# Epoch 23/100
# 23/23 - 0s - 4ms/step - loss: 148.9517 - val_loss: 164.5077
# Epoch 24/100
# 23/23 - 0s - 4ms/step - loss: 145.8832 - val_loss: 163.8345
# Epoch 25/100
# 23/23 - 0s - 4ms/step - loss: 143.9872 - val_loss: 165.2480
# Epoch 26/100
# 23/23 - 0s - 4ms/step - loss: 141.3584 - val_loss: 161.8563
# Epoch 27/100
# 23/23 - 0s - 4ms/step - loss: 139.0961 - val_loss: 161.7435
# Epoch 28/100
# 23/23 - 0s - 4ms/step - loss: 137.0768 - val_loss: 162.4744
# Epoch 29/100
# 23/23 - 0s - 4ms/step - loss: 134.7670 - val_loss: 158.3288
# Epoch 30/100
# 23/23 - 0s - 4ms/step - loss: 132.4728 - val_loss: 159.5566
# Epoch 31/100
# 23/23 - 0s - 4ms/step - loss: 131.3182 - val_loss: 160.7267
# Epoch 32/100
# 23/23 - 0s - 4ms/step - loss: 128.5061 - val_loss: 160.2095
# Epoch 33/100
# 23/23 - 0s - 4ms/step - loss: 126.5742 - val_loss: 156.4310
# Epoch 34/100
# 23/23 - 0s - 4ms/step - loss: 124.7195 - val_loss: 157.9655
# Epoch 35/100
# 23/23 - 0s - 4ms/step - loss: 122.5872 - val_loss: 155.3885
# Epoch 36/100
# 23/23 - 0s - 4ms/step - loss: 120.2575 - val_loss: 157.8027
# Epoch 37/100
# 23/23 - 0s - 4ms/step - loss: 118.5967 - val_loss: 157.1853
# Epoch 38/100
# 23/23 - 0s - 4ms/step - loss: 116.4562 - val_loss: 157.2729
# Epoch 39/100
# 23/23 - 0s - 4ms/step - loss: 115.3895 - val_loss: 154.5058
# Epoch 40/100
# 23/23 - 0s - 4ms/step - loss: 113.3179 - val_loss: 157.7984
# Epoch 41/100
# 23/23 - 0s - 4ms/step - loss: 110.8045 - val_loss: 156.9196
# Epoch 42/100
# 23/23 - 0s - 4ms/step - loss: 108.1311 - val_loss: 154.3130
# Epoch 43/100
# 23/23 - 0s - 4ms/step - loss: 106.3796 - val_loss: 154.0286
# Epoch 44/100
# 23/23 - 0s - 4ms/step - loss: 104.4155 - val_loss: 156.7192
# Epoch 45/100
# 23/23 - 0s - 4ms/step - loss: 102.3265 - val_loss: 151.1754
# Epoch 46/100
# 23/23 - 0s - 4ms/step - loss: 101.3423 - val_loss: 159.0048
# Epoch 47/100
# 23/23 - 0s - 4ms/step - loss: 98.7277 - val_loss: 149.1215
# Epoch 48/100
# 23/23 - 0s - 4ms/step - loss: 97.0144 - val_loss: 153.9837
# Epoch 49/100
# 23/23 - 0s - 4ms/step - loss: 94.7212 - val_loss: 151.1580
# Epoch 50/100
# 23/23 - 0s - 4ms/step - loss: 92.6376 - val_loss: 153.8578
# Epoch 51/100
# 23/23 - 0s - 4ms/step - loss: 90.9902 - val_loss: 148.3317
# Epoch 52/100
# 23/23 - 0s - 4ms/step - loss: 88.8780 - val_loss: 152.5392
# Epoch 53/100
# 23/23 - 0s - 4ms/step - loss: 86.9488 - val_loss: 151.9938
# Epoch 54/100
# 23/23 - 0s - 4ms/step - loss: 84.7997 - val_loss: 142.5357
# Epoch 55/100
# 23/23 - 0s - 4ms/step - loss: 82.6548 - val_loss: 151.6370
# Epoch 56/100
# 23/23 - 0s - 4ms/step - loss: 80.0623 - val_loss: 147.7839
# Epoch 57/100
# 23/23 - 0s - 4ms/step - loss: 77.6707 - val_loss: 143.5216
# Epoch 58/100
# 23/23 - 0s - 4ms/step - loss: 76.3235 - val_loss: 155.9659
# Epoch 59/100
# 23/23 - 0s - 4ms/step - loss: 74.7993 - val_loss: 140.1462
# Epoch 60/100
# 23/23 - 0s - 4ms/step - loss: 71.6256 - val_loss: 143.8822
# Epoch 61/100
# 23/23 - 0s - 4ms/step - loss: 70.1488 - val_loss: 136.4755
# Epoch 62/100
# 23/23 - 0s - 4ms/step - loss: 68.1020 - val_loss: 147.0481
# Epoch 63/100
# 23/23 - 0s - 4ms/step - loss: 66.5627 - val_loss: 136.6386
# Epoch 64/100
# 23/23 - 0s - 4ms/step - loss: 64.8640 - val_loss: 144.1256
# Epoch 65/100
# 23/23 - 0s - 4ms/step - loss: 63.2213 - val_loss: 135.5364
# Epoch 66/100
# 23/23 - 0s - 4ms/step - loss: 61.5061 - val_loss: 140.2043
# Epoch 67/100
# 23/23 - 0s - 4ms/step - loss: 59.6171 - val_loss: 134.0373
# Epoch 68/100
# 23/23 - 0s - 4ms/step - loss: 57.4292 - val_loss: 138.5714
# Epoch 69/100
# 23/23 - 0s - 4ms/step - loss: 55.9119 - val_loss: 134.2720
# Epoch 70/100
# 23/23 - 0s - 4ms/step - loss: 54.6063 - val_loss: 133.7442
# Epoch 71/100
# 23/23 - 0s - 4ms/step - loss: 52.8801 - val_loss: 132.7610
# Epoch 72/100
# 23/23 - 0s - 4ms/step - loss: 51.2463 - val_loss: 137.6833
# Epoch 73/100
# 23/23 - 0s - 4ms/step - loss: 50.6614 - val_loss: 150.5278
# Epoch 74/100
# 23/23 - 0s - 4ms/step - loss: 50.5920 - val_loss: 126.1499
# Epoch 75/100
# 23/23 - 0s - 4ms/step - loss: 47.8848 - val_loss: 138.7855
# Epoch 76/100
# 23/23 - 0s - 4ms/step - loss: 46.4544 - val_loss: 134.3588
# Epoch 77/100
# 23/23 - 0s - 4ms/step - loss: 45.5443 - val_loss: 141.3991
# Epoch 78/100
# 23/23 - 0s - 4ms/step - loss: 44.3389 - val_loss: 140.8764
# Epoch 79/100
# 23/23 - 0s - 4ms/step - loss: 43.9079 - val_loss: 133.0603
# Epoch 80/100
# 23/23 - 0s - 4ms/step - loss: 42.8483 - val_loss: 141.3162
# Epoch 81/100
# 23/23 - 0s - 4ms/step - loss: 42.0335 - val_loss: 142.9871
# Epoch 82/100
# 23/23 - 0s - 4ms/step - loss: 41.3051 - val_loss: 143.8084
# Epoch 83/100
# 23/23 - 0s - 4ms/step - loss: 40.5687 - val_loss: 148.1708
# Epoch 84/100
# 23/23 - 0s - 4ms/step - loss: 39.8923 - val_loss: 136.6634
# Epoch 85/100
# 23/23 - 0s - 4ms/step - loss: 39.3337 - val_loss: 157.0113
# Epoch 86/100
# 23/23 - 0s - 4ms/step - loss: 39.0522 - val_loss: 143.8911
# Epoch 87/100
# 23/23 - 0s - 4ms/step - loss: 38.6069 - val_loss: 140.1596
# Epoch 88/100
# 23/23 - 0s - 4ms/step - loss: 37.5894 - val_loss: 144.8277
# Epoch 89/100
# 23/23 - 0s - 4ms/step - loss: 37.0365 - val_loss: 140.8037
# Epoch 90/100
# 23/23 - 0s - 4ms/step - loss: 36.7297 - val_loss: 149.1114
# Epoch 91/100
# 23/23 - 0s - 4ms/step - loss: 36.5244 - val_loss: 157.0930
# Epoch 92/100
# 23/23 - 0s - 4ms/step - loss: 36.1762 - val_loss: 135.3365
# Epoch 93/100
# 23/23 - 0s - 4ms/step - loss: 36.0216 - val_loss: 136.3418
# Epoch 94/100
# 23/23 - 0s - 4ms/step - loss: 36.0651 - val_loss: 147.4480
# Epoch 95/100
# 23/23 - 0s - 4ms/step - loss: 34.4273 - val_loss: 134.3994
# Epoch 96/100
# 23/23 - 0s - 4ms/step - loss: 34.1884 - val_loss: 158.8885
# Epoch 97/100
# 23/23 - 0s - 4ms/step - loss: 33.9972 - val_loss: 144.0377
# Epoch 98/100
# 23/23 - 0s - 4ms/step - loss: 33.3137 - val_loss: 145.8624
# Epoch 99/100
# 23/23 - 0s - 4ms/step - loss: 33.2237 - val_loss: 134.4853
# Epoch 100/100
# 23/23 - 0s - 4ms/step - loss: 32.8568 - val_loss: 149.2285

# %% [markdown]
# <h3>Practica Ejercicio 1</h3>

# %% [markdown]
# Ahora, utilizando el mismo conjunto de datos, intenta recrear un modelo de regresión que tenga cinco capas ocultas, cada una con 50 nodos y funciones de activación ReLU, una única capa de salida, y que se optimice usando el optimizador Adam.

# %%
def regression_model():
    input_colm = predictors_norm.shape[1] # Number of input features
    # create model
    model = Sequential()
    model.add(Input(shape=(input_colm,)))  # Set the number of input features
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))  # Output layer

    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# <h3>Practica Ejercicio 2</h3>

# %% [markdown]
# Entrena y evalúa el modelo simultáneamente utilizando el método fit(), reservando el 10% de los datos para validación y entrenando el modelo durante 100 épocas.

# %%
model = regression_model()
model.fit(predictors_norm, target, validation_split=0.1, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 29/29 - 1s - 42ms/step - loss: 1477.8386 - val_loss: 890.4549
# Epoch 2/100
# 29/29 - 0s - 4ms/step - loss: 591.4163 - val_loss: 227.5870
# Epoch 3/100
# 29/29 - 0s - 4ms/step - loss: 251.3950 - val_loss: 216.1946
# Epoch 4/100
# 29/29 - 0s - 4ms/step - loss: 211.5045 - val_loss: 207.8772
# Epoch 5/100
# 29/29 - 0s - 4ms/step - loss: 195.1099 - val_loss: 201.5299
# Epoch 6/100
# 29/29 - 0s - 4ms/step - loss: 175.2847 - val_loss: 174.8601
# Epoch 7/100
# 29/29 - 0s - 4ms/step - loss: 160.1906 - val_loss: 173.1013
# Epoch 8/100
# 29/29 - 0s - 4ms/step - loss: 146.1870 - val_loss: 148.9711
# Epoch 9/100
# 29/29 - 0s - 4ms/step - loss: 134.6067 - val_loss: 150.3008
# Epoch 10/100
# 29/29 - 0s - 4ms/step - loss: 115.2153 - val_loss: 121.7324
# Epoch 11/100
# 29/29 - 0s - 4ms/step - loss: 100.0126 - val_loss: 127.5155
# Epoch 12/100
# 29/29 - 0s - 3ms/step - loss: 85.5360 - val_loss: 111.8407
# Epoch 13/100
# 29/29 - 0s - 3ms/step - loss: 72.3650 - val_loss: 88.3791
# Epoch 14/100
# 29/29 - 0s - 3ms/step - loss: 61.6923 - val_loss: 71.1108
# Epoch 15/100
# 29/29 - 0s - 3ms/step - loss: 54.8162 - val_loss: 62.3836
# Epoch 16/100
# 29/29 - 0s - 3ms/step - loss: 50.6122 - val_loss: 54.8351
# Epoch 17/100
# 29/29 - 0s - 3ms/step - loss: 46.2153 - val_loss: 48.3245
# Epoch 18/100
# 29/29 - 0s - 3ms/step - loss: 42.8909 - val_loss: 39.9719
# Epoch 19/100
# 29/29 - 0s - 3ms/step - loss: 40.6121 - val_loss: 44.0996
# Epoch 20/100
# 29/29 - 0s - 3ms/step - loss: 37.8636 - val_loss: 37.7586
# Epoch 21/100
# 29/29 - 0s - 3ms/step - loss: 35.8480 - val_loss: 38.0586
# Epoch 22/100
# 29/29 - 0s - 3ms/step - loss: 34.8857 - val_loss: 37.3411
# Epoch 23/100
# 29/29 - 0s - 3ms/step - loss: 32.9091 - val_loss: 34.5917
# Epoch 24/100
# 29/29 - 0s - 3ms/step - loss: 32.1306 - val_loss: 39.0149
# Epoch 25/100
# 29/29 - 0s - 3ms/step - loss: 31.3665 - val_loss: 43.3458
# Epoch 26/100
# 29/29 - 0s - 3ms/step - loss: 31.3706 - val_loss: 31.5062
# Epoch 27/100
# 29/29 - 0s - 3ms/step - loss: 28.4046 - val_loss: 33.1258
# Epoch 28/100
# 29/29 - 0s - 3ms/step - loss: 28.5476 - val_loss: 31.2446
# Epoch 29/100
# 29/29 - 0s - 3ms/step - loss: 26.5802 - val_loss: 30.0774
# Epoch 30/100
# 29/29 - 0s - 3ms/step - loss: 26.2484 - val_loss: 32.1502
# Epoch 31/100
# 29/29 - 0s - 4ms/step - loss: 25.0330 - val_loss: 30.1584
# Epoch 32/100
# 29/29 - 0s - 3ms/step - loss: 24.4498 - val_loss: 28.6012
# Epoch 33/100
# 29/29 - 0s - 3ms/step - loss: 23.8409 - val_loss: 29.8443
# Epoch 34/100
# 29/29 - 0s - 3ms/step - loss: 22.8202 - val_loss: 27.5262
# Epoch 35/100
# 29/29 - 0s - 4ms/step - loss: 22.6016 - val_loss: 31.5538
# Epoch 36/100
# 29/29 - 0s - 4ms/step - loss: 21.8162 - val_loss: 29.2775
# Epoch 37/100
# 29/29 - 0s - 3ms/step - loss: 22.5618 - val_loss: 37.2369
# Epoch 38/100
# 29/29 - 0s - 4ms/step - loss: 20.9977 - val_loss: 26.9536
# Epoch 39/100
# 29/29 - 0s - 4ms/step - loss: 20.0163 - val_loss: 37.8080
# Epoch 40/100
# 29/29 - 0s - 4ms/step - loss: 21.7063 - val_loss: 27.4842
# Epoch 41/100
# 29/29 - 0s - 4ms/step - loss: 19.4263 - val_loss: 26.4796
# Epoch 42/100
# 29/29 - 0s - 3ms/step - loss: 21.7966 - val_loss: 23.7110
# Epoch 43/100
# 29/29 - 0s - 4ms/step - loss: 19.5567 - val_loss: 23.6603
# Epoch 44/100
# 29/29 - 0s - 3ms/step - loss: 19.3214 - val_loss: 30.9265
# Epoch 45/100
# 29/29 - 0s - 3ms/step - loss: 17.9425 - val_loss: 27.7785
# Epoch 46/100
# 29/29 - 0s - 4ms/step - loss: 18.8310 - val_loss: 24.9460
# Epoch 47/100
# 29/29 - 0s - 3ms/step - loss: 17.7731 - val_loss: 26.1898
# Epoch 48/100
# 29/29 - 0s - 3ms/step - loss: 17.9083 - val_loss: 23.6252
# Epoch 49/100
# 29/29 - 0s - 3ms/step - loss: 17.1695 - val_loss: 21.7037
# Epoch 50/100
# 29/29 - 0s - 3ms/step - loss: 16.6593 - val_loss: 21.3571
# Epoch 51/100
# 29/29 - 0s - 4ms/step - loss: 15.6333 - val_loss: 24.6724
# Epoch 52/100
# 29/29 - 0s - 4ms/step - loss: 17.0138 - val_loss: 20.9598
# Epoch 53/100
# 29/29 - 0s - 3ms/step - loss: 15.5174 - val_loss: 20.5281
# Epoch 54/100
# 29/29 - 0s - 3ms/step - loss: 16.4250 - val_loss: 20.9918
# Epoch 55/100
# 29/29 - 0s - 3ms/step - loss: 15.3021 - val_loss: 19.2467
# Epoch 56/100
# 29/29 - 0s - 3ms/step - loss: 14.6388 - val_loss: 18.7027
# Epoch 57/100
# 29/29 - 0s - 3ms/step - loss: 15.2297 - val_loss: 19.4484
# Epoch 58/100
# 29/29 - 0s - 3ms/step - loss: 14.9940 - val_loss: 18.3458
# Epoch 59/100
# 29/29 - 0s - 3ms/step - loss: 15.0976 - val_loss: 17.9126
# Epoch 60/100
# 29/29 - 0s - 3ms/step - loss: 14.8824 - val_loss: 17.5894
# Epoch 61/100
# 29/29 - 0s - 3ms/step - loss: 14.0534 - val_loss: 16.9663
# Epoch 62/100
# 29/29 - 0s - 4ms/step - loss: 13.4835 - val_loss: 17.2363
# Epoch 63/100
# 29/29 - 0s - 4ms/step - loss: 13.5133 - val_loss: 17.0342
# Epoch 64/100
# 29/29 - 0s - 4ms/step - loss: 14.2460 - val_loss: 18.0260
# Epoch 65/100
# 29/29 - 0s - 4ms/step - loss: 13.7361 - val_loss: 18.2403
# Epoch 66/100
# 29/29 - 0s - 4ms/step - loss: 13.6156 - val_loss: 18.0022
# Epoch 67/100
# 29/29 - 0s - 4ms/step - loss: 14.1750 - val_loss: 19.2105
# Epoch 68/100
# 29/29 - 0s - 4ms/step - loss: 13.2476 - val_loss: 19.2992
# Epoch 69/100
# 29/29 - 0s - 4ms/step - loss: 13.2724 - val_loss: 16.2144
# Epoch 70/100
# 29/29 - 0s - 4ms/step - loss: 12.5666 - val_loss: 17.0433
# Epoch 71/100
# 29/29 - 0s - 3ms/step - loss: 12.7831 - val_loss: 16.0106
# Epoch 72/100
# 29/29 - 0s - 4ms/step - loss: 12.7559 - val_loss: 17.0913
# Epoch 73/100
# 29/29 - 0s - 4ms/step - loss: 12.4564 - val_loss: 16.0620
# Epoch 74/100
# 29/29 - 0s - 4ms/step - loss: 12.3902 - val_loss: 16.2417
# Epoch 75/100
# 29/29 - 0s - 4ms/step - loss: 13.5975 - val_loss: 20.4043
# Epoch 76/100
# 29/29 - 0s - 4ms/step - loss: 12.9070 - val_loss: 18.1015
# Epoch 77/100
# 29/29 - 0s - 4ms/step - loss: 12.8752 - val_loss: 15.2962
# Epoch 78/100
# 29/29 - 0s - 4ms/step - loss: 12.0599 - val_loss: 14.8422
# Epoch 79/100
# 29/29 - 0s - 4ms/step - loss: 12.5011 - val_loss: 15.1369
# Epoch 80/100
# 29/29 - 0s - 4ms/step - loss: 11.9890 - val_loss: 15.4631
# Epoch 81/100
# 29/29 - 0s - 4ms/step - loss: 11.5383 - val_loss: 14.0219
# Epoch 82/100
# 29/29 - 0s - 4ms/step - loss: 11.3039 - val_loss: 13.9099
# Epoch 83/100
# 29/29 - 0s - 4ms/step - loss: 11.7439 - val_loss: 13.8189
# Epoch 84/100
# 29/29 - 0s - 4ms/step - loss: 11.8527 - val_loss: 14.1752
# Epoch 85/100
# 29/29 - 0s - 4ms/step - loss: 11.4425 - val_loss: 16.5222
# Epoch 86/100
# 29/29 - 0s - 4ms/step - loss: 11.7305 - val_loss: 15.8527
# Epoch 87/100
# 29/29 - 0s - 4ms/step - loss: 10.7020 - val_loss: 13.8449
# Epoch 88/100
# 29/29 - 0s - 4ms/step - loss: 10.3006 - val_loss: 14.1839
# Epoch 89/100
# 29/29 - 0s - 4ms/step - loss: 10.7016 - val_loss: 13.9450
# Epoch 90/100
# 29/29 - 0s - 4ms/step - loss: 11.1817 - val_loss: 15.2071
# Epoch 91/100
# 29/29 - 0s - 4ms/step - loss: 12.6624 - val_loss: 13.5759
# Epoch 92/100
# 29/29 - 0s - 4ms/step - loss: 11.0136 - val_loss: 14.7377
# Epoch 93/100
# 29/29 - 0s - 4ms/step - loss: 11.0136 - val_loss: 13.5252
# Epoch 94/100
# 29/29 - 0s - 4ms/step - loss: 12.0296 - val_loss: 23.9257
# Epoch 95/100
# 29/29 - 0s - 4ms/step - loss: 12.5044 - val_loss: 13.3661
# Epoch 96/100
# 29/29 - 0s - 4ms/step - loss: 11.0827 - val_loss: 14.4441
# Epoch 97/100
# 29/29 - 0s - 4ms/step - loss: 10.7477 - val_loss: 18.6886
# Epoch 98/100
# 29/29 - 0s - 4ms/step - loss: 10.3647 - val_loss: 15.7615
# Epoch 99/100
# 29/29 - 0s - 4ms/step - loss: 10.0875 - val_loss: 18.0261
# Epoch 100/100
# 29/29 - 0s - 4ms/step - loss: 12.3330 - val_loss: 12.2569

# %% [markdown]
# Basándonos en los resultados, observamos que:
#
# Agregar más capas ocultas al modelo aumenta su capacidad para aprender y representar relaciones complejas dentro de los datos. Esto permite que el modelo identifique mejor los patrones, por lo que se vuelve más efectivo al ajustar los datos de entrenamiento y potencialmente mejorar sus predicciones.
#
# Al reducir la proporción de datos reservados para validación y utilizar una mayor porción para el entrenamiento, el modelo tiene acceso a más ejemplos para aprender. Estos datos de entrenamiento adicionales ayudan al modelo a mejorar su comprensión de las tendencias subyacentes, lo que puede conducir a un mejor desempeño general.
