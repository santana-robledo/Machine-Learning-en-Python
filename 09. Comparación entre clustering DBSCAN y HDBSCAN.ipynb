# %% [markdown]
# # Comparación de Clustering DBSCAN y HDBSCAN
#
# Después de completar este laboratorio, podrás:
#
# Usar scikit-learn para implementar modelos de clustering DBSCAN y HDBSCAN en datos reales.
#
# Comparar el desempeño de ambos modelos.

# %% [markdown]
# En este laboratorio, crearás dos modelos de clustering utilizando datos recopilados por StatCan, que contienen los nombres, tipos y ubicaciones de instalaciones culturales y artísticas en Canadá.
# Nos centraremos en las ubicaciones de los museos proporcionadas en todo Canadá.
#
# Fuente de los datos: Base de Datos Abierta de Instalaciones Culturales y Artísticas (ODCAF)
#
# Una colección de datos abiertos que contiene los nombres, tipos y ubicaciones de instalaciones culturales y artísticas en Canadá.
# Se publica bajo la Licencia de Gobierno Abierto - Canadá.
# Los diferentes tipos de instalaciones se etiquetan bajo 'ODCAF_Facility_Type'.
#
# Página principal:
#
# https://www.statcan.gc.ca/en/lode/databases/odcaf
#
# Enlace al archivo zip:
#
# https://www150.statcan.gc.ca/n1/en/pub/21-26-0001/2020001/ODCAF_V1.0.zip?st=brOCT3Ry

# %%
# !pip install numpy==2.2.0
# !pip install pandas==2.2.3
# !pip install scikit-learn==1.6.0
# !pip install matplotlib==3.9.3
# !pip install hdbscan==0.8.40
# !pip install geopandas==1.0.1
# !pip install contextily==1.6.2
# !pip install shapely==2.0.6
# Out:
# Requirement already satisfied: numpy==2.2.0 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (2.2.0)
# Requirement already satisfied: pandas==2.2.3 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from pandas==2.2.3) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from pandas==2.2.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from pandas==2.2.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from pandas==2.2.3) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.3) (1.17.0)
# Requirement already satisfied: scikit-learn==1.6.0 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from scikit-learn==1.6.0) (2.2.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from scikit-learn==1.6.0) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from scikit-learn==1.6.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from scikit-learn==1.6.0) (3.6.0)
# Requirement already satisfied: matplotlib==3.9.3 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from matplotlib==3.9.3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from matplotlib==3.9.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from matplotlib==3.9.3) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from matplotlib==3.9.3) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from matplotlib==3.9.3) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from matplotlib==3.9.3) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from matplotlib==3.9.3) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from matplotlib==3.9.3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from matplotlib==3.9.3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.9.3) (1.17.0)
# Collecting hdbscan==0.8.40
#   Using cached hdbscan-0.8.40.tar.gz (6.9 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from hdbscan==0.8.40) (2.2.0)
# Requirement already satisfied: scipy>=1.0 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from hdbscan==0.8.40) (1.16.3)
# Requirement already satisfied: scikit-learn>=0.20 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from hdbscan==0.8.40) (1.6.0)
# Requirement already satisfied: joblib>=1.0 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from hdbscan==0.8.40) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from scikit-learn>=0.20->hdbscan==0.8.40) (3.6.0)
# Building wheels for collected packages: hdbscan
#   Building wheel for hdbscan (pyproject.toml): started
#   Building wheel for hdbscan (pyproject.toml): finished with status 'error'
# Failed to build hdbscan
#   error: subprocess-exited-with-error
#
#   × Building wheel for hdbscan (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [39 lines of output]
#       C:\Users\Josue Santana Robled\AppData\Local\Temp\pip-build-env-l3j8ra48\overlay\Lib\site-packages\setuptools\_distutils\dist.py:289: UserWarning: Unknown distribution option: 'test_suite'
#         warnings.warn(msg)
#       C:\Users\Josue Santana Robled\AppData\Local\Temp\pip-build-env-l3j8ra48\overlay\Lib\site-packages\setuptools\_distutils\dist.py:289: UserWarning: Unknown distribution option: 'tests_require'
#         warnings.warn(msg)
#       C:\Users\Josue Santana Robled\AppData\Local\Temp\pip-build-env-l3j8ra48\overlay\Lib\site-packages\setuptools\dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         self._finalize_license_expression()
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-313\hdbscan
#       copying hdbscan\branches.py -> build\lib.win-amd64-cpython-313\hdbscan
#       copying hdbscan\flat.py -> build\lib.win-amd64-cpython-313\hdbscan
#       copying hdbscan\hdbscan_.py -> build\lib.win-amd64-cpython-313\hdbscan
#       copying hdbscan\plots.py -> build\lib.win-amd64-cpython-313\hdbscan
#       copying hdbscan\prediction.py -> build\lib.win-amd64-cpython-313\hdbscan
#       copying hdbscan\robust_single_linkage_.py -> build\lib.win-amd64-cpython-313\hdbscan
#       copying hdbscan\validity.py -> build\lib.win-amd64-cpython-313\hdbscan
#       copying hdbscan\__init__.py -> build\lib.win-amd64-cpython-313\hdbscan
#       creating build\lib.win-amd64-cpython-313\hdbscan\tests
#       copying hdbscan\tests\test_branches.py -> build\lib.win-amd64-cpython-313\hdbscan\tests
#       copying hdbscan\tests\test_flat.py -> build\lib.win-amd64-cpython-313\hdbscan\tests
#       copying hdbscan\tests\test_hdbscan.py -> build\lib.win-amd64-cpython-313\hdbscan\tests
#       copying hdbscan\tests\test_prediction_utils.py -> build\lib.win-amd64-cpython-313\hdbscan\tests
#       copying hdbscan\tests\test_rsl.py -> build\lib.win-amd64-cpython-313\hdbscan\tests
#       copying hdbscan\tests\__init__.py -> build\lib.win-amd64-cpython-313\hdbscan\tests
#       running build_ext
#       building 'hdbscan._hdbscan_tree' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for hdbscan
# error: failed-wheel-build-for-install
#
# × Failed to build installable wheels for some pyproject.toml based projects
# ╰─> hdbscan
# Requirement already satisfied: geopandas==1.0.1 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from geopandas==1.0.1) (2.2.0)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from geopandas==1.0.1) (0.12.1)
# Requirement already satisfied: packaging in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from geopandas==1.0.1) (25.0)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from geopandas==1.0.1) (2.2.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from geopandas==1.0.1) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from geopandas==1.0.1) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from pandas>=1.4.0->geopandas==1.0.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from pandas>=1.4.0->geopandas==1.0.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from pandas>=1.4.0->geopandas==1.0.1) (2025.2)
# Requirement already satisfied: certifi in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from pyogrio>=0.7.2->geopandas==1.0.1) (2025.11.12)
# Requirement already satisfied: six>=1.5 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas==1.0.1) (1.17.0)
# Requirement already satisfied: contextily==1.6.2 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (1.6.2)
# Requirement already satisfied: geopy in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from contextily==1.6.2) (2.4.1)
# Requirement already satisfied: matplotlib in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from contextily==1.6.2) (3.9.3)
# Requirement already satisfied: mercantile in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from contextily==1.6.2) (1.2.1)
# Requirement already satisfied: pillow in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from contextily==1.6.2) (12.0.0)
# Requirement already satisfied: rasterio in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from contextily==1.6.2) (1.4.3)
# Requirement already satisfied: requests in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from contextily==1.6.2) (2.32.5)
# Requirement already satisfied: joblib in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from contextily==1.6.2) (1.5.2)
# Requirement already satisfied: xyzservices in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from contextily==1.6.2) (2025.11.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from geopy->contextily==1.6.2) (2.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from matplotlib->contextily==1.6.2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from matplotlib->contextily==1.6.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from matplotlib->contextily==1.6.2) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from matplotlib->contextily==1.6.2) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from matplotlib->contextily==1.6.2) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from matplotlib->contextily==1.6.2) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from matplotlib->contextily==1.6.2) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from matplotlib->contextily==1.6.2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->contextily==1.6.2) (1.17.0)
# Requirement already satisfied: click>=3.0 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from mercantile->contextily==1.6.2) (8.3.1)
# Requirement already satisfied: colorama in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from click>=3.0->mercantile->contextily==1.6.2) (0.4.6)
# Requirement already satisfied: affine in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from rasterio->contextily==1.6.2) (2.4.0)
# Requirement already satisfied: attrs in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from rasterio->contextily==1.6.2) (25.4.0)
# Requirement already satisfied: certifi in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from rasterio->contextily==1.6.2) (2025.11.12)
# Requirement already satisfied: cligj>=0.5 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from rasterio->contextily==1.6.2) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from rasterio->contextily==1.6.2) (1.1.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from requests->contextily==1.6.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from requests->contextily==1.6.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from requests->contextily==1.6.2) (2.5.0)
# Requirement already satisfied: shapely==2.0.6 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (2.0.6)
# Requirement already satisfied: numpy<3,>=1.14 in c:\users\josue santana robled\pycharmprojects\coursera\.venv\lib\site-packages (from shapely==2.0.6) (2.2.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
import hdbscan
from sklearn.preprocessing import StandardScaler

# geographical tools
import geopandas as gpd  # pandas dataframe-like geodataframes for geographical data
import contextily as ctx  # used for obtianing a basemap of Canada
from shapely.geometry import Point

import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 5
#       3 import matplotlib.pyplot as plt
#       4 from sklearn.cluster import DBSCAN
# ----> 5 import hdbscan
#       6 from sklearn.preprocessing import StandardScaler
#       8 # geographical tools
#
# ModuleNotFoundError: No module named 'hdbscan'

# %% [markdown]
# Descargar el mapa de Canadá como referencia
#
# Para obtener un contexto adecuado del resultado final de este laboratorio, necesitas un mapa de referencia de Canadá.
# Ejecuta la celda a continuación para extraerlo en este entorno del laboratorio.

# %%
import requests
import zipfile
import io
import os

# URL of the ZIP file on the cloud server
zip_file_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/YcUk-ytgrPkmvZAh5bf7zA/Canada.zip'

# Directory to save the extracted TIFF file
output_dir = './'
os.makedirs(output_dir, exist_ok=True)

# Step 1: Download the ZIP file
response = requests.get(zip_file_url)
response.raise_for_status()  # Ensure the request was successful
# Step 2: Open the ZIP file in memory
with zipfile.ZipFile(io.BytesIO(response.content)) as zip_ref:
    # Step 3: Iterate over the files in the ZIP
    for file_name in zip_ref.namelist():
        if file_name.endswith('.tif'):  # Check if it's a TIFF file
            # Step 4: Extract the TIFF file
            zip_ref.extract(file_name, output_dir)
            print(f"Downloaded and extracted: {file_name}")
# Out:
# Downloaded and extracted: Canada.tif

# %% [markdown]
# ## Incluir una función de visualización
#
# Se proporciona el código de una función auxiliar para ayudarte a graficar tus resultados.
# Aunque no necesitas preocuparte por los detalles, es bastante instructivo, ya que utiliza un dataframe de geopandas y un basemap para dibujar los puntos de los clústeres coloreados sobre un mapa de Canadá.

# %%
# Write a function that plots clustered locations and overlays them on a basemap.

def plot_clustered_locations(df,  title='Museums Clustered by Proximity'):
    """
    Plots clustered locations and overlays on a basemap.

    Parameters:
    - df: DataFrame containing 'Latitude', 'Longitude', and 'Cluster' columns
    - title: str, title of the plot
    """

    # Load the coordinates intto a GeoDataFrame
    gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['Longitude'], df['Latitude']), crs="EPSG:4326")

    # Reproject to Web Mercator to align with basemap
    gdf = gdf.to_crs(epsg=3857)

    # Create the plot
    fig, ax = plt.subplots(figsize=(15, 10))

    # Separate non-noise, or clustered points from noise, or unclustered points
    non_noise = gdf[gdf['Cluster'] != -1]
    noise = gdf[gdf['Cluster'] == -1]

    # Plot noise points
    noise.plot(ax=ax, color='k', markersize=30, ec='r', alpha=1, label='Noise')

    # Plot clustered points, colured by 'Cluster' number
    non_noise.plot(ax=ax, column='Cluster', cmap='tab10', markersize=30, ec='k', legend=False, alpha=0.6)

    # Add basemap of  Canada
    ctx.add_basemap(ax, source='./Canada.tif', zoom=4)

    # Format plot
    plt.title(title, )
    plt.xlabel('Longitude', )
    plt.ylabel('Latitude', )
    ax.set_xticks([])
    ax.set_yticks([])
    plt.tight_layout()

    # Show the plot
    plt.show()

# %% [markdown]
# ## Explora los datos y extrae lo que necesites de ellos

# %%
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/r-maSj5Yegvw2sJraT15FA/ODCAF-v1-0.csv'
df = pd.read_csv(url, encoding = "ISO-8859-1")
df.head()
# Out:
#    Index                      Facility_Name            Source_Facility_Type  \
# 0      1                   #Hashtag Gallery                              ..
# 1      2  'Ksan Historical Village & Museum  historic site-building or park
# 2      3               'School Days' Museum       community/regional museum
# 3      4                   10 Austin Street       built heritage properties
# 4      5              10 Gates Dancing Inc.                            arts
#
#          ODCAF_Facility_Type                      Provider Unit Street_No  \
# 0                    gallery                       toronto   ..       801
# 1                     museum  canadian museums association   ..      1500
# 2                     museum  canadian museums association   ..       427
# 3  heritage or historic site                       moncton   ..        10
# 4              miscellaneous                        ottawa   ..        ..
#
#    Street_Name Postal_Code         City Prov_Terr  \
# 0  dundas st w     M6J 1V2      toronto        on
# 1       62 hwy     V0J 1Y0     hazelton        bc
# 2     queen st     E3B 5R6  fredericton        nb
# 3    austin st     E1C 1Z6      moncton        nb
# 4           ..          ..       ottawa        on
#
#                                Source_Format_Address     CSD_Name   CSDUID  \
# 0                                    801 dundas st w      Toronto  3520005
# 1  1500 hwy 62 hazelton british columbia v0j 1y0 ...     Hazelton  5949022
# 2  427 queen st fredericton new brunswick e3b 5r6...  Fredericton  1310032
# 3                                       10 austin st      Moncton  1307022
# 4                                                 ..       Ottawa  3506008
#
#   PRUID     Latitude     Longitude
# 0    35  43.65169472  -79.40803272
# 1    59   55.2645508  -127.6428124
# 2    13    45.963283   -66.6419017
# 3    13  46.09247776  -64.78022946
# 4    35  45.40856224  -75.71536766

# %% [markdown]
# Ejercicio 1
#
# Explora la tabla. ¿Cómo se representan los valores faltantes (missing values) en este conjunto de datos?

# %% [markdown]
# Las cadenas que consisten en dos puntos '..' indican valores faltantes.
# También podrían existir campos vacíos o NaN.

# %% [markdown]
# ### Ejercicio 2
#
# Muestra los tipos de instalaciones y sus conteos.

# %%
df.ODCAF_Facility_Type.value_counts()
# Out:
# ODCAF_Facility_Type
# library or archives                     3013
# museum                                  1938
# gallery                                  810
# heritage or historic site                620
# theatre/performance and concert hall     583
# festival site                            346
# miscellaneous                            343
# art or cultural centre                   225
# artist                                    94
# Name: count, dtype: int64

# %% [markdown]
# ### Ejercicio 3
# Filtra los datos para incluir únicamente museos.
# Verifica tus resultados. ¿Obtuviste tantos como esperabas?

# %%
df = df[df.ODCAF_Facility_Type == 'museum']
df.ODCAF_Facility_Type.value_counts()
# Out:
# ODCAF_Facility_Type
# museum    1938
# Name: count, dtype: int64

# %% [markdown]
# ### Ejercicio 4
# Selecciona únicamente las características de Latitud y Longitud como entradas para nuestro problema de clustering.
# Además, muestra información sobre las coordenadas, como los conteos y los tipos de datos.

# %%
df = df[['Latitude', 'Longitude']]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1938 entries, 1 to 7969
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Latitude   1938 non-null   object
#  1   Longitude  1938 non-null   object
# dtypes: object(2)
# memory usage: 45.4+ KB

# %% [markdown]
# ### Ejercicio 5
# Necesitaremos que estas coordenadas sean floats, no objetos.
# Elimina cualquier museo que no tenga coordenadas y convierte las coordenadas restantes a floats.

# %%
df = df[df.Latitude!='..']

df[['Latitude','Longitude']] = df[['Latitude','Longitude']].astype('float')

# %% [markdown]
# ## Construir un modelo DBSCAN
# Escala correctamente las coordenadas para DBSCAN (ya que DBSCAN es sensible a la escala)

# %%
# In this case we know how to scale the coordinates. Using standardization would be an error becaues we aren't using the full range of the lat/lng coordinates.
# Since latitude has a range of +/- 90 degrees and longitude ranges from 0 to 360 degrees, the correct scaling is to double the longitude coordinates (or half the Latitudes)
coords_scaled = df.copy()
coords_scaled["Latitude"] = 2*coords_scaled["Latitude"]

# %% [markdown]
# ### Aplicar DBSCAN con distancia Euclidiana a las coordenadas escaladas
#
# En este caso, los parámetros de vecindad razonables ya están seleccionados para ti.
# Siéntete libre de experimentar.

# %%
min_samples=3 # minimum number of samples needed to form a neighbourhood
eps=1.0 # neighbourhood search radius
metric='euclidean' # distance measure

dbscan = DBSCAN(eps=eps, min_samples=min_samples, metric=metric).fit(coords_scaled)

# %% [markdown]
# ### Agregar etiquetas de clúster al DataFrame

# %%
df['Cluster'] = dbscan.fit_predict(coords_scaled)  # Assign the cluster labels

# Display the size of each cluster
df['Cluster'].value_counts()
# Out:
# Cluster
#  4     701
#  2     192
#  1     181
#  7     134
#  3      94
# -1      79
#  6      30
#  10     27
#  8      21
#  11     15
#  15     13
#  20     11
#  16     10
#  19      9
#  27      8
#  12      7
#  26      6
#  5       6
#  24      6
#  28      6
#  14      6
#  18      6
#  13      4
#  9       4
#  22      4
#  0       3
#  23      3
#  21      3
#  17      3
#  25      3
#  29      3
#  31      3
#  30      3
#  32      3
# Name: count, dtype: int64

# %% [markdown]
# Como puedes ver, hay dos clústeres relativamente grandes y 79 puntos etiquetados como ruido (-1).
#
# ### Grafica los museos en un basemap de Canadá, coloreados según la etiqueta del clúster.

# %%
plot_clustered_locations(df, title='Museums Clustered by Proximity')

# %% [markdown]
# - ¿Qué ves?
# - ¿Cuál es el tamaño del grupo más pequeño?
# - ¿Crees que los grupos tienen sentido en términos de lo que esperas ver?
# - ¿Crees que debería haber más grupos en algunas regiones? ¿Por qué?

# %% [markdown]
# Una cosa clave para notar aquí es que los grupos no tienen una densidad uniforme.
#
# Por ejemplo, los puntos están bastante densamente agrupados en algunas regiones, pero son relativamente dispersos en otras.
#
# DBSCAN aglomera los grupos vecinos cuando están lo suficientemente cerca.
#
# Veamos cómo funciona un algoritmo de agrupamiento basado en densidad jerárquica como HDBSCAN.

# %% [markdown]
# ## Construir un modelo de clustering HDBSCAN
# En esta etapa, ya has cargado tus datos y extraído las coordenadas de los museos en un dataframe, df.
#
# También has almacenado las coordenadas debidamente escaladas en el array 'coords_scaled'.
#
# Solo queda:
#
# Ajustar y transformar HDBSCAN a tus coordenadas escaladas
# Extraer las etiquetas de los clusters
# Graficar los resultados en el mismo mapa base que antes
# Se han seleccionado parámetros razonables de HDBSCAN para que comiences.

# %% [markdown]
# #### Inicializa un módelo HDBSCAN

# %%
min_samples=None
min_cluster_size=3
hdb = hdbscan.HDBSCAN(min_samples=min_samples, min_cluster_size=min_cluster_size, metric='euclidean')  # You can adjust parameters as needed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 min_samples=None
#       2 min_cluster_size=3
# ----> 3 hdb = hdbscan.HDBSCAN(min_samples=min_samples, min_cluster_size=min_cluster_size, metric='euclidean')  # You can adjust parameters as needed
#
# NameError: name 'hdbscan' is not defined

# %% [markdown]
# ## Ejercicio 6. Asigna las etiquetas de los clusters a tu dataframe con coordenadas sin escalar y muestra el conteo de cada etiqueta de cluster.

# %%
df['Cluster'] = hdb.fit_predict(coords_scaled)  # Another way to assign the labels

# Display the size of each cluster
df['Cluster'].value_counts()

# %% [markdown]
# Como puedes ver, a diferencia del caso de DBSCAN, los clusters tienen un tamaño bastante uniforme, aunque se identifica una cantidad considerable de ruido.
#
# ## Ejercicio 7. Grafica los museos agrupados jerárquicamente en un mapa base de Canadá, coloreados según la etiqueta de cluster.

# %%
plot_clustered_locations(df, title='Museums Hierarchically Clustered by Proximity')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 plot_clustered_locations(df, title='Museums Hierarchically Clustered by Proximity')
#
# Cell In[6], line 13, in plot_clustered_locations(df, title)
#       4 """
#       5 Plots clustered locations and overlays on a basemap.
#       6
#    (...)      9 - title: str, title of the plot
#      10 """
#      12 # Load the coordinates intto a GeoDataFrame
# ---> 13 gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['Longitude'], df['Latitude']), crs="EPSG:4326")
#      15 # Reproject to Web Mercator to align with basemap
#      16 gdf = gdf.to_crs(epsg=3857)
#
# NameError: name 'gpd' is not defined

# %% [markdown]
# ### Comentarios finales

# %% [markdown]
# Observa detenidamente el mapa.
#
# - ¿Qué es diferente en estos resultados comparados con DBSCAN?
# Podría parecer que hay más puntos identificados como ruido, ¿pero es realmente así?
# - ¿Puedes ver las variaciones en la densidad que HDBSCAN captura?
# En la práctica, querrías investigar mucho más a fondo, pero al menos aquí tienes la idea.
